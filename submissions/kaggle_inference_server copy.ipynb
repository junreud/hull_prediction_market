# %% [markdown]
# # 🎯 Hull Tactical Market Prediction - Local Training
#
# **로컬 환경에서 모델 학습 후 artifacts 저장**
#
# ## 📌 사용법
#
# ### Step 1: 데이터 준비
#
# `data/raw/` 폴더에 다음 파일이 있어야 합니다:
# - `train.csv`
# - `test.csv`
#
# ### Step 2: 노트북 실행
#
# 1. **Run All** 클릭
# 2. 약 30분 소요:
#    - Return Model 학습 (~10 min)
#    - Risk Model 학습 (~10 min)
#    - Position Strategy 최적화 (~10 min)
#
# ### Step 3: 결과 확인
#
# 학습 완료 후 다음 파일들이 생성됩니다:
# ```
# artifacts/
# ├── models_optimized/
# │   └── return_model.pkl
# ├── models_risk_optimized/
# │   └── risk_model.pkl
# └── position_strategy.json
# ```
#
# 이 파일들을 Kaggle Dataset에 업로드하세요!
#
# **Good luck! 🚀**

# %% [markdown]
# ## 1️⃣ Setup: 환경 설정

# %%
import os
import sys
from pathlib import Path

print("="*80)
print("LOCAL TRAINING ENVIRONMENT SETUP")
print("="*80)

# 프로젝트 루트 경로
project_root = Path.cwd().parent if Path.cwd().name == 'submissions' else Path.cwd()

# Python path에 추가
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print(f"✓ Project root: {project_root}")

# 데이터 경로 확인
data_path = project_root / "data" / "raw"
train_file = data_path / "train.csv"
test_file = data_path / "test.csv"

if train_file.exists() and test_file.exists():
    print(f"✓ Data files found:")
    print(f"  - {train_file}")
    print(f"  - {test_file}")
else:
    print(f"\n⚠️  Data files not found!")
    print(f"  Expected location: {data_path}")
    print(f"  Please download train.csv and test.csv from Kaggle")

# artifacts 폴더 생성
artifacts_dir = project_root / "artifacts"
(artifacts_dir / "models_optimized").mkdir(parents=True, exist_ok=True)
(artifacts_dir / "models_risk_optimized").mkdir(parents=True, exist_ok=True)

print(f"\n✓ Artifacts directory ready: {artifacts_dir}")
print("\n✅ Setup complete!")
# Out:
# ================================================================================
# LOCAL TRAINING ENVIRONMENT SETUP
# ================================================================================
# ✓ Project root: /Users/gimjunseog/projects/hull_prediction_market
#
# ⚠️  Data files not found!
#   Expected location: /Users/gimjunseog/projects/hull_prediction_market/data/raw
#   Please download train.csv and test.csv from Kaggle
#
# ✓ Artifacts directory ready: /Users/gimjunseog/projects/hull_prediction_market/artifacts
#
# ✅ Setup complete!

# %% [markdown]
# ## 2️⃣ Step 1: Train Return Model (~10 min)

# %%
print("="*80)
print("STEP 1/3: TRAINING RETURN MODEL")
print("="*80)

# Return model 학습 스크립트 실행
script_path = project_root / "scripts" / "optimize_return_model.py"

if script_path.exists():
    print(f"▶ Running: {script_path.name}\n")
    
    # 현재 디렉토리를 프로젝트 루트로 변경
    original_cwd = os.getcwd()
    os.chdir(project_root)
    
    # %run {script_path}
    
    # 원래 디렉토리로 복귀
    os.chdir(original_cwd)
    
    print("\n✅ Return model training complete!")
    print(f"📊 Model saved to: artifacts/models_optimized/")
else:
    raise FileNotFoundError(f"Script not found: {script_path}")
# Out:
# 2025-11-14 21:01:51,264 - prediction_market - INFO - Feature Engineering initialized
# 2025-11-14 21:01:51,265 - prediction_market - INFO - Rolling windows: [5, 10, 20, 40, 60]
# 2025-11-14 21:01:51,265 - prediction_market - INFO - Lag periods: [1, 2, 3, 5, 10]
# 2025-11-14 21:01:51,266 - prediction_market - INFO - Scaler type: robust
# 2025-11-14 21:01:51,266 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:51,266 - prediction_market - INFO - RETURN MODEL OPTIMIZATION PIPELINE
# 2025-11-14 21:01:51,267 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:51,267 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:01:51,267 - prediction_market - INFO - STARTING FULL OPTIMIZATION PIPELINE
# 2025-11-14 21:01:51,268 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:51,268 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:01:51,269 - prediction_market - INFO - STEP 1: DATA LOADING AND PREPROCESSING
# 2025-11-14 21:01:51,269 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:51,269 - prediction_market - INFO - Starting: Data Loading and Preprocessing
# 2025-11-14 21:01:51,270 - prediction_market - INFO -
# 1.1 Loading raw data...
# 2025-11-14 21:01:51,270 - prediction_market - INFO - Starting: Loading data
# 2025-11-14 21:01:51,271 - prediction_market - INFO - Loading train data from data/raw/train.csv
# 2025-11-14 21:01:51,265 - prediction_market - INFO - Rolling windows: [5, 10, 20, 40, 60]
# 2025-11-14 21:01:51,265 - prediction_market - INFO - Lag periods: [1, 2, 3, 5, 10]
# 2025-11-14 21:01:51,266 - prediction_market - INFO - Scaler type: robust
# 2025-11-14 21:01:51,266 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:51,266 - prediction_market - INFO - RETURN MODEL OPTIMIZATION PIPELINE
# 2025-11-14 21:01:51,267 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:51,267 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:01:51,267 - prediction_market - INFO - STARTING FULL OPTIMIZATION PIPELINE
# 2025-11-14 21:01:51,268 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:51,268 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:01:51,269 - prediction_market - INFO - STEP 1: DATA LOADING AND PREPROCESSING
# 2025-11-14 21:01:51,269 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:51,269 - prediction_market - INFO - Starting: Data Loading and Preprocessing
# 2025-11-14 21:01:51,270 - prediction_market - INFO -
# 1.1 Loading raw data...
# 2025-11-14 21:01:51,270 - prediction_market - INFO - Starting: Loading data
# 2025-11-14 21:01:51,271 - prediction_market - INFO - Loading train data from data/raw/train.csv
# 2025-11-14 21:01:51,401 - prediction_market - INFO - Loading test data from data/raw/test.csv
# 2025-11-14 21:01:51,403 - prediction_market - INFO - Feature groups identified:
# 2025-11-14 21:01:51,404 - prediction_market - INFO -   M: 18 features
# 2025-11-14 21:01:51,404 - prediction_market - INFO -   E: 20 features
# 2025-11-14 21:01:51,404 - prediction_market - INFO -   I: 9 features
# 2025-11-14 21:01:51,405 - prediction_market - INFO -   P: 13 features
# 2025-11-14 21:01:51,405 - prediction_market - INFO -   V: 13 features
# 2025-11-14 21:01:51,405 - prediction_market - INFO -   S: 12 features
# 2025-11-14 21:01:51,401 - prediction_market - INFO - Loading test data from data/raw/test.csv
# 2025-11-14 21:01:51,403 - prediction_market - INFO - Feature groups identified:
# 2025-11-14 21:01:51,404 - prediction_market - INFO -   M: 18 features
# 2025-11-14 21:01:51,404 - prediction_market - INFO -   E: 20 features
# 2025-11-14 21:01:51,404 - prediction_market - INFO -   I: 9 features
# 2025-11-14 21:01:51,405 - prediction_market - INFO -   P: 13 features
# 2025-11-14 21:01:51,405 - prediction_market - INFO -   V: 13 features
# 2025-11-14 21:01:51,405 - prediction_market - INFO -   S: 12 features
# 2025-11-14 21:01:51,405 - prediction_market - INFO -   D: 9 features
# 2025-11-14 21:01:51,418 - prediction_market - INFO - Data loaded and sorted by date_id
# 2025-11-14 21:01:51,418 - prediction_market - INFO - Completed: Loading data - Time: 0.15s
# 2025-11-14 21:01:51,419 - prediction_market - INFO - ✓ Loaded 9021 samples
# 2025-11-14 21:01:51,419 - prediction_market - INFO -
# 1.2 Preprocessing data...
# 2025-11-14 21:01:51,420 - prediction_market - INFO - ============================================================
# 2025-11-14 21:01:51,420 - prediction_market - INFO - PREPROCESSING PIPELINE
# 2025-11-14 21:01:51,421 - prediction_market - INFO - ============================================================
# 2025-11-14 21:01:51,421 - prediction_market - INFO - Starting: Winsorizing outliers
# 2025-11-14 21:01:51,405 - prediction_market - INFO -   D: 9 features
# 2025-11-14 21:01:51,418 - prediction_market - INFO - Data loaded and sorted by date_id
# 2025-11-14 21:01:51,418 - prediction_market - INFO - Completed: Loading data - Time: 0.15s
# 2025-11-14 21:01:51,419 - prediction_market - INFO - ✓ Loaded 9021 samples
# 2025-11-14 21:01:51,419 - prediction_market - INFO -
# 1.2 Preprocessing data...
# 2025-11-14 21:01:51,420 - prediction_market - INFO - ============================================================
# 2025-11-14 21:01:51,420 - prediction_market - INFO - PREPROCESSING PIPELINE
# 2025-11-14 21:01:51,421 - prediction_market - INFO - ============================================================
# 2025-11-14 21:01:51,421 - prediction_market - INFO - Starting: Winsorizing outliers
# ================================================================================
# STEP 1/3: TRAINING RETURN MODEL
# ================================================================================
# ▶ Running: optimize_return_model.py
# 2025-11-14 21:01:51,886 - prediction_market - INFO - Rolling winsorization complete with limits (0.001, 0.001), window=60
# 2025-11-14 21:01:51,886 - prediction_market - INFO - Completed: Winsorizing outliers - Time: 0.47s
# 2025-11-14 21:01:51,887 - prediction_market - INFO - Starting: Normalizing features
# 2025-11-14 21:01:51,886 - prediction_market - INFO - Completed: Winsorizing outliers - Time: 0.47s
# 2025-11-14 21:01:51,887 - prediction_market - INFO - Starting: Normalizing features
# 2025-11-14 21:01:51,963 - prediction_market - INFO - Rank-Gauss normalization: 85 features
# 2025-11-14 21:01:51,963 - prediction_market - INFO - Completed: Normalizing features - Time: 0.08s
# 2025-11-14 21:01:51,963 - prediction_market - INFO - Starting: Scaling features
# 2025-11-14 21:01:51,972 - prediction_market - INFO - Scaled 18 features in group M
# 2025-11-14 21:01:51,963 - prediction_market - INFO - Rank-Gauss normalization: 85 features
# 2025-11-14 21:01:51,963 - prediction_market - INFO - Completed: Normalizing features - Time: 0.08s
# 2025-11-14 21:01:51,963 - prediction_market - INFO - Starting: Scaling features
# 2025-11-14 21:01:51,972 - prediction_market - INFO - Scaled 18 features in group M
# 2025-11-14 21:01:51,978 - prediction_market - INFO - Scaled 20 features in group E
# 2025-11-14 21:01:51,982 - prediction_market - INFO - Scaled 9 features in group I
# 2025-11-14 21:01:51,986 - prediction_market - INFO - Scaled 13 features in group P
# 2025-11-14 21:01:51,978 - prediction_market - INFO - Scaled 20 features in group E
# 2025-11-14 21:01:51,982 - prediction_market - INFO - Scaled 9 features in group I
# 2025-11-14 21:01:51,986 - prediction_market - INFO - Scaled 13 features in group P
# 2025-11-14 21:01:51,991 - prediction_market - INFO - Scaled 13 features in group V
# 2025-11-14 21:01:51,996 - prediction_market - INFO - Scaled 12 features in group S
# 2025-11-14 21:01:51,996 - prediction_market - INFO - Completed: Scaling features - Time: 0.03s
# 2025-11-14 21:01:51,996 - prediction_market - INFO - ============================================================
# 2025-11-14 21:01:51,997 - prediction_market - INFO - PREPROCESSING COMPLETE
# 2025-11-14 21:01:51,997 - prediction_market - INFO - ============================================================
# 2025-11-14 21:01:51,998 - prediction_market - INFO - ✓ Preprocessing complete: (9021, 98)
# 2025-11-14 21:01:51,998 - prediction_market - INFO - Completed: Data Loading and Preprocessing - Time: 0.73s
# 2025-11-14 21:01:51,999 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:01:51,999 - prediction_market - INFO - STEP 2: FEATURE ENGINEERING
# 2025-11-14 21:01:52,000 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:52,000 - prediction_market - INFO - Starting: Feature Engineering
# 2025-11-14 21:01:51,991 - prediction_market - INFO - Scaled 13 features in group V
# 2025-11-14 21:01:51,996 - prediction_market - INFO - Scaled 12 features in group S
# 2025-11-14 21:01:51,996 - prediction_market - INFO - Completed: Scaling features - Time: 0.03s
# 2025-11-14 21:01:51,996 - prediction_market - INFO - ============================================================
# 2025-11-14 21:01:51,997 - prediction_market - INFO - PREPROCESSING COMPLETE
# 2025-11-14 21:01:51,997 - prediction_market - INFO - ============================================================
# 2025-11-14 21:01:51,998 - prediction_market - INFO - ✓ Preprocessing complete: (9021, 98)
# 2025-11-14 21:01:51,998 - prediction_market - INFO - Completed: Data Loading and Preprocessing - Time: 0.73s
# 2025-11-14 21:01:51,999 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:01:51,999 - prediction_market - INFO - STEP 2: FEATURE ENGINEERING
# 2025-11-14 21:01:52,000 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:52,000 - prediction_market - INFO - Starting: Feature Engineering
# 2025-11-14 21:01:52,005 - prediction_market - INFO -
# 2.1 Adding time period features...
# 2025-11-14 21:01:52,007 - prediction_market - INFO - Created time period features:
# 2025-11-14 21:01:52,008 - prediction_market - INFO -   Early period (< 2255): 2255 samples
# 2025-11-14 21:01:52,008 - prediction_market - INFO -   Mid period (2255-6765): 4510 samples
# 2025-11-14 21:01:52,009 - prediction_market - INFO -   Recent period (>= 6765): 2256 samples
# 2025-11-14 21:01:52,009 - prediction_market - INFO - ✓ Time period features added
# 2025-11-14 21:01:52,010 - prediction_market - INFO -
# 2.2 Adding market regime features...
# 2025-11-14 21:01:52,012 - prediction_market - INFO - Added auto-detected regime: regime_high_vol (521 periods)
# 2025-11-14 21:01:52,012 - prediction_market - INFO - ✓ Market regime features added
# 2025-11-14 21:01:52,012 - prediction_market - INFO -
# 2.3 Creating engineered features...
# 2025-11-14 21:01:52,013 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:52,013 - prediction_market - INFO - Starting Feature Engineering Pipeline
# 2025-11-14 21:01:52,014 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:52,005 - prediction_market - INFO -
# 2.1 Adding time period features...
# 2025-11-14 21:01:52,007 - prediction_market - INFO - Created time period features:
# 2025-11-14 21:01:52,008 - prediction_market - INFO -   Early period (< 2255): 2255 samples
# 2025-11-14 21:01:52,008 - prediction_market - INFO -   Mid period (2255-6765): 4510 samples
# 2025-11-14 21:01:52,009 - prediction_market - INFO -   Recent period (>= 6765): 2256 samples
# 2025-11-14 21:01:52,009 - prediction_market - INFO - ✓ Time period features added
# 2025-11-14 21:01:52,010 - prediction_market - INFO -
# 2.2 Adding market regime features...
# 2025-11-14 21:01:52,012 - prediction_market - INFO - Added auto-detected regime: regime_high_vol (521 periods)
# 2025-11-14 21:01:52,012 - prediction_market - INFO - ✓ Market regime features added
# 2025-11-14 21:01:52,012 - prediction_market - INFO -
# 2.3 Creating engineered features...
# 2025-11-14 21:01:52,013 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:52,013 - prediction_market - INFO - Starting Feature Engineering Pipeline
# 2025-11-14 21:01:52,014 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:52,016 - prediction_market - INFO - Starting: Feature Engineering
# 2025-11-14 21:01:52,017 - prediction_market - INFO -
# Original features by group:
# 2025-11-14 21:01:52,017 - prediction_market - INFO -   M (Market): 18 features
# 2025-11-14 21:01:52,017 - prediction_market - INFO -   E (Economic): 20 features
# 2025-11-14 21:01:52,018 - prediction_market - INFO -   P (Price): 13 features
# 2025-11-14 21:01:52,019 - prediction_market - INFO -   V (Volatility): 13 features
# 2025-11-14 21:01:52,020 - prediction_market - INFO -   S (Sentiment): 12 features
# 2025-11-14 21:01:52,020 - prediction_market - INFO -
# 1. Creating rolling features...
# 2025-11-14 21:01:52,016 - prediction_market - INFO - Starting: Feature Engineering
# 2025-11-14 21:01:52,017 - prediction_market - INFO -
# Original features by group:
# 2025-11-14 21:01:52,017 - prediction_market - INFO -   M (Market): 18 features
# 2025-11-14 21:01:52,017 - prediction_market - INFO -   E (Economic): 20 features
# 2025-11-14 21:01:52,018 - prediction_market - INFO -   P (Price): 13 features
# 2025-11-14 21:01:52,019 - prediction_market - INFO -   V (Volatility): 13 features
# 2025-11-14 21:01:52,020 - prediction_market - INFO -   S (Sentiment): 12 features
# 2025-11-14 21:01:52,020 - prediction_market - INFO -
# 1. Creating rolling features...
# 2025-11-14 21:01:52,282 - prediction_market - INFO - Created rolling features for 31 columns
# 2025-11-14 21:01:52,283 - prediction_market - INFO -
# 2. Creating lag features...
# 2025-11-14 21:01:52,282 - prediction_market - INFO - Created rolling features for 31 columns
# 2025-11-14 21:01:52,283 - prediction_market - INFO -
# 2. Creating lag features...
# 2025-11-14 21:01:52,423 - prediction_market - INFO - Created lag features for 51 columns
# 2025-11-14 21:01:52,424 - prediction_market - INFO -
# 3. Creating difference features...
# 2025-11-14 21:01:52,423 - prediction_market - INFO - Created lag features for 51 columns
# 2025-11-14 21:01:52,424 - prediction_market - INFO -
# 3. Creating difference features...
# 2025-11-14 21:01:52,555 - prediction_market - INFO - Created difference features for 31 columns
# 2025-11-14 21:01:52,556 - prediction_market - INFO -
# 4. Creating interaction features...
# 2025-11-14 21:01:52,555 - prediction_market - INFO - Created difference features for 31 columns
# 2025-11-14 21:01:52,556 - prediction_market - INFO -
# 4. Creating interaction features...
# 2025-11-14 21:01:52,654 - prediction_market - INFO - Created interaction features for 3 group pairs
# 2025-11-14 21:01:52,655 - prediction_market - INFO -
# 5. Creating technical features...
# 2025-11-14 21:01:52,654 - prediction_market - INFO - Created interaction features for 3 group pairs
# 2025-11-14 21:01:52,655 - prediction_market - INFO -
# 5. Creating technical features...
# 2025-11-14 21:01:52,767 - prediction_market - INFO - Created technical features for 5 columns
# 2025-11-14 21:01:52,768 - prediction_market - INFO -
# 6. Creating regime features...
# 2025-11-14 21:01:52,767 - prediction_market - INFO - Created technical features for 5 columns
# 2025-11-14 21:01:52,768 - prediction_market - INFO -
# 6. Creating regime features...
# 2025-11-14 21:01:53,785 - prediction_market - INFO - Created regime features for 3 columns
# 2025-11-14 21:01:53,787 - prediction_market - INFO - Completed: Feature Engineering - Time: 1.77s
# 2025-11-14 21:01:53,789 - prediction_market - INFO -
# ✓ Feature engineering complete!
# 2025-11-14 21:01:53,789 - prediction_market - INFO -   Original features: 100
# 2025-11-14 21:01:53,790 - prediction_market - INFO -   Engineered features: 1497
# 2025-11-14 21:01:53,790 - prediction_market - INFO -   Total features: 1597
# 2025-11-14 21:01:53,791 - prediction_market - INFO -
# ✓ Feature engineering complete
# 2025-11-14 21:01:53,791 - prediction_market - INFO -   Original features: 100
# 2025-11-14 21:01:53,792 - prediction_market - INFO -   Engineered features: 1497
# 2025-11-14 21:01:53,792 - prediction_market - INFO -   Total features: 1597
# 2025-11-14 21:01:53,792 - prediction_market - INFO - Completed: Feature Engineering - Time: 1.79s
# 2025-11-14 21:01:53,792 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:01:53,793 - prediction_market - INFO - STEP 3: FEATURE SELECTION
# 2025-11-14 21:01:53,793 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:53,793 - prediction_market - INFO - Starting: Feature Selection
# 2025-11-14 21:01:53,793 - prediction_market - INFO -
# 3.1 Selecting top 200 features by correlation...
# 2025-11-14 21:01:53,794 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:53,794 - prediction_market - INFO - Feature Selection
# 2025-11-14 21:01:53,795 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:53,795 - prediction_market - INFO - Method: correlation
# 2025-11-14 21:01:53,796 - prediction_market - INFO - Top N: 200
# 2025-11-14 21:01:53,797 - prediction_market - INFO - Threshold: None
# 2025-11-14 21:01:53,798 - prediction_market - INFO -
# Total features to evaluate: 1595
# 2025-11-14 21:01:53,785 - prediction_market - INFO - Created regime features for 3 columns
# 2025-11-14 21:01:53,787 - prediction_market - INFO - Completed: Feature Engineering - Time: 1.77s
# 2025-11-14 21:01:53,789 - prediction_market - INFO -
# ✓ Feature engineering complete!
# 2025-11-14 21:01:53,789 - prediction_market - INFO -   Original features: 100
# 2025-11-14 21:01:53,790 - prediction_market - INFO -   Engineered features: 1497
# 2025-11-14 21:01:53,790 - prediction_market - INFO -   Total features: 1597
# 2025-11-14 21:01:53,791 - prediction_market - INFO -
# ✓ Feature engineering complete
# 2025-11-14 21:01:53,791 - prediction_market - INFO -   Original features: 100
# 2025-11-14 21:01:53,792 - prediction_market - INFO -   Engineered features: 1497
# 2025-11-14 21:01:53,792 - prediction_market - INFO -   Total features: 1597
# 2025-11-14 21:01:53,792 - prediction_market - INFO - Completed: Feature Engineering - Time: 1.79s
# 2025-11-14 21:01:53,792 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:01:53,793 - prediction_market - INFO - STEP 3: FEATURE SELECTION
# 2025-11-14 21:01:53,793 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:53,793 - prediction_market - INFO - Starting: Feature Selection
# 2025-11-14 21:01:53,793 - prediction_market - INFO -
# 3.1 Selecting top 200 features by correlation...
# 2025-11-14 21:01:53,794 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:53,794 - prediction_market - INFO - Feature Selection
# 2025-11-14 21:01:53,795 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:01:53,795 - prediction_market - INFO - Method: correlation
# 2025-11-14 21:01:53,796 - prediction_market - INFO - Top N: 200
# 2025-11-14 21:01:53,797 - prediction_market - INFO - Threshold: None
# 2025-11-14 21:01:53,798 - prediction_market - INFO -
# Total features to evaluate: 1595
# 2025-11-14 21:02:20,996 - prediction_market - INFO -
# ✓ Selected top 200 features
# 2025-11-14 21:02:20,998 - prediction_market - INFO -
# Top 20 features by correlation:
# 2025-11-14 21:02:20,998 - prediction_market - INFO -   P8_diff_1: 0.0749
# 2025-11-14 21:02:20,998 - prediction_market - INFO -   P10_diff_1: 0.0669
# 2025-11-14 21:02:20,999 - prediction_market - INFO -   P10_diff_5: 0.0572
# 2025-11-14 21:02:20,999 - prediction_market - INFO -   M4: 0.0535
# 2025-11-14 21:02:20,999 - prediction_market - INFO -   M9_diff_1: 0.0530
# 2025-11-14 21:02:21,000 - prediction_market - INFO -   P8_diff_5: 0.0526
# 2025-11-14 21:02:21,000 - prediction_market - INFO -   P8_accel: 0.0515
# 2025-11-14 21:02:21,001 - prediction_market - INFO -   M4_dev_60: 0.0511
# 2025-11-14 21:02:21,001 - prediction_market - INFO -   P11_diff_5: 0.0504
# 2025-11-14 21:02:21,002 - prediction_market - INFO -   M4_dev_40: 0.0500
# 2025-11-14 21:02:21,002 - prediction_market - INFO -   P11_diff_1: 0.0479
# 2025-11-14 21:02:21,003 - prediction_market - INFO -   M4_dev_20: 0.0479
# 2025-11-14 21:02:21,003 - prediction_market - INFO -   P2_diff_1: 0.0470
# 2025-11-14 21:02:21,003 - prediction_market - INFO -   P8_diff_10: 0.0452
# 2025-11-14 21:02:21,004 - prediction_market - INFO -   M4_dev_10: 0.0435
# 2025-11-14 21:02:21,004 - prediction_market - INFO -   M9_dev_10: 0.0434
# 2025-11-14 21:02:21,005 - prediction_market - INFO -   P10_diff_10: 0.0432
# 2025-11-14 21:02:21,005 - prediction_market - INFO -   M4_zscore_60: 0.0431
# 2025-11-14 21:02:21,005 - prediction_market - INFO -   M4_roll_min_5: 0.0422
# 2025-11-14 21:02:21,005 - prediction_market - INFO -   P2_diff_5: 0.0421
# 2025-11-14 21:02:20,996 - prediction_market - INFO -
# ✓ Selected top 200 features
# 2025-11-14 21:02:20,998 - prediction_market - INFO -
# Top 20 features by correlation:
# 2025-11-14 21:02:20,998 - prediction_market - INFO -   P8_diff_1: 0.0749
# 2025-11-14 21:02:20,998 - prediction_market - INFO -   P10_diff_1: 0.0669
# 2025-11-14 21:02:20,999 - prediction_market - INFO -   P10_diff_5: 0.0572
# 2025-11-14 21:02:20,999 - prediction_market - INFO -   M4: 0.0535
# 2025-11-14 21:02:20,999 - prediction_market - INFO -   M9_diff_1: 0.0530
# 2025-11-14 21:02:21,000 - prediction_market - INFO -   P8_diff_5: 0.0526
# 2025-11-14 21:02:21,000 - prediction_market - INFO -   P8_accel: 0.0515
# 2025-11-14 21:02:21,001 - prediction_market - INFO -   M4_dev_60: 0.0511
# 2025-11-14 21:02:21,001 - prediction_market - INFO -   P11_diff_5: 0.0504
# 2025-11-14 21:02:21,002 - prediction_market - INFO -   M4_dev_40: 0.0500
# 2025-11-14 21:02:21,002 - prediction_market - INFO -   P11_diff_1: 0.0479
# 2025-11-14 21:02:21,003 - prediction_market - INFO -   M4_dev_20: 0.0479
# 2025-11-14 21:02:21,003 - prediction_market - INFO -   P2_diff_1: 0.0470
# 2025-11-14 21:02:21,003 - prediction_market - INFO -   P8_diff_10: 0.0452
# 2025-11-14 21:02:21,004 - prediction_market - INFO -   M4_dev_10: 0.0435
# 2025-11-14 21:02:21,004 - prediction_market - INFO -   M9_dev_10: 0.0434
# 2025-11-14 21:02:21,005 - prediction_market - INFO -   P10_diff_10: 0.0432
# 2025-11-14 21:02:21,005 - prediction_market - INFO -   M4_zscore_60: 0.0431
# 2025-11-14 21:02:21,005 - prediction_market - INFO -   M4_roll_min_5: 0.0422
# 2025-11-14 21:02:21,005 - prediction_market - INFO -   P2_diff_5: 0.0421
# 2025-11-14 21:02:21,014 - prediction_market - INFO -
# ✓ Feature selection complete
# 2025-11-14 21:02:21,014 - prediction_market - INFO -   Selected features: 200
# 2025-11-14 21:02:21,015 - prediction_market - INFO -   Dataframe shape: (9021, 204)
# 2025-11-14 21:02:21,015 - prediction_market - INFO -
# 3.2 Removing correlated features (threshold=0.95)...
# 2025-11-14 21:02:21,016 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:21,016 - prediction_market - INFO - Removing Correlated Features
# 2025-11-14 21:02:21,017 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:21,017 - prediction_market - INFO - Threshold: 0.95
# 2025-11-14 21:02:21,014 - prediction_market - INFO -
# ✓ Feature selection complete
# 2025-11-14 21:02:21,014 - prediction_market - INFO -   Selected features: 200
# 2025-11-14 21:02:21,015 - prediction_market - INFO -   Dataframe shape: (9021, 204)
# 2025-11-14 21:02:21,015 - prediction_market - INFO -
# 3.2 Removing correlated features (threshold=0.95)...
# 2025-11-14 21:02:21,016 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:21,016 - prediction_market - INFO - Removing Correlated Features
# 2025-11-14 21:02:21,017 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:21,017 - prediction_market - INFO - Threshold: 0.95
# 2025-11-14 21:02:21,589 - prediction_market - INFO -
# ✓ Found 52 highly correlated features to remove
# 2025-11-14 21:02:21,590 - prediction_market - INFO -
# Removing features (sample):
# 2025-11-14 21:02:21,590 - prediction_market - INFO -   M12_roll_max_5
# 2025-11-14 21:02:21,590 - prediction_market - INFO -   M17_roll_max_60
# 2025-11-14 21:02:21,591 - prediction_market - INFO -   M12_roll_mean_20
# 2025-11-14 21:02:21,591 - prediction_market - INFO -   D1
# 2025-11-14 21:02:21,592 - prediction_market - INFO -   M17_roll_min_20
# 2025-11-14 21:02:21,592 - prediction_market - INFO -   M17_roll_mean_40
# 2025-11-14 21:02:21,592 - prediction_market - INFO -   M1_lag_2
# 2025-11-14 21:02:21,593 - prediction_market - INFO -   M1_roll_max_5
# 2025-11-14 21:02:21,593 - prediction_market - INFO -   V13_dev_60
# 2025-11-14 21:02:21,593 - prediction_market - INFO -   M2_dev_60
# 2025-11-14 21:02:21,596 - prediction_market - INFO -
# ✓ Correlation filtering complete
# 2025-11-14 21:02:21,597 - prediction_market - INFO -   Removed features: 52
# 2025-11-14 21:02:21,597 - prediction_market - INFO -   Remaining features: 150
# 2025-11-14 21:02:21,597 - prediction_market - INFO -
# ✓ Feature selection complete
# 2025-11-14 21:02:21,598 - prediction_market - INFO -   Final features: 148
# 2025-11-14 21:02:21,589 - prediction_market - INFO -
# ✓ Found 52 highly correlated features to remove
# 2025-11-14 21:02:21,590 - prediction_market - INFO -
# Removing features (sample):
# 2025-11-14 21:02:21,590 - prediction_market - INFO -   M12_roll_max_5
# 2025-11-14 21:02:21,590 - prediction_market - INFO -   M17_roll_max_60
# 2025-11-14 21:02:21,591 - prediction_market - INFO -   M12_roll_mean_20
# 2025-11-14 21:02:21,591 - prediction_market - INFO -   D1
# 2025-11-14 21:02:21,592 - prediction_market - INFO -   M17_roll_min_20
# 2025-11-14 21:02:21,592 - prediction_market - INFO -   M17_roll_mean_40
# 2025-11-14 21:02:21,592 - prediction_market - INFO -   M1_lag_2
# 2025-11-14 21:02:21,593 - prediction_market - INFO -   M1_roll_max_5
# 2025-11-14 21:02:21,593 - prediction_market - INFO -   V13_dev_60
# 2025-11-14 21:02:21,593 - prediction_market - INFO -   M2_dev_60
# 2025-11-14 21:02:21,596 - prediction_market - INFO -
# ✓ Correlation filtering complete
# 2025-11-14 21:02:21,597 - prediction_market - INFO -   Removed features: 52
# 2025-11-14 21:02:21,597 - prediction_market - INFO -   Remaining features: 150
# 2025-11-14 21:02:21,597 - prediction_market - INFO -
# ✓ Feature selection complete
# 2025-11-14 21:02:21,598 - prediction_market - INFO -   Final features: 148
# 2025-11-14 21:02:21,614 - prediction_market - INFO - Completed: Feature Selection - Time: 27.82s
# 2025-11-14 21:02:21,615 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:02:21,615 - prediction_market - INFO - STEP 4: HYPERPARAMETER TUNING
# 2025-11-14 21:02:21,615 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:21,616 - prediction_market - INFO - Starting: Hyperparameter Tuning
# 2025-11-14 21:02:21,614 - prediction_market - INFO - Completed: Feature Selection - Time: 27.82s
# 2025-11-14 21:02:21,615 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:02:21,615 - prediction_market - INFO - STEP 4: HYPERPARAMETER TUNING
# 2025-11-14 21:02:21,615 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:21,616 - prediction_market - INFO - Starting: Hyperparameter Tuning
# 2025-11-14 21:02:21,634 - prediction_market - INFO - CV Strategy initialized
# 2025-11-14 21:02:21,635 - prediction_market - INFO - Configuration: {'n_splits': 5, 'embargo': 5, 'purge': True, 'purge_period': 15, 'train_ratio': 0.8}
# 2025-11-14 21:02:21,635 - prediction_market - INFO - OptunaLightGBMTuner initialized (config_section=tuning)
# 2025-11-14 21:02:21,635 - prediction_market - INFO - Trials: 1, Timeout: None, Jobs: 1
# 2025-11-14 21:02:21,636 - prediction_market - INFO -
# 4.1 Running Optuna optimization (1 trials)...
# 2025-11-14 21:02:21,636 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:21,637 - prediction_market - INFO - Starting Hyperparameter Optimization
# 2025-11-14 21:02:21,637 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:21,637 - prediction_market - INFO -
# Features: 148
# 2025-11-14 21:02:21,637 - prediction_market - INFO - Samples: 9021
# 2025-11-14 21:02:21,638 - prediction_market - INFO - Target: forward_returns
# 2025-11-14 21:02:21,634 - prediction_market - INFO - CV Strategy initialized
# 2025-11-14 21:02:21,635 - prediction_market - INFO - Configuration: {'n_splits': 5, 'embargo': 5, 'purge': True, 'purge_period': 15, 'train_ratio': 0.8}
# 2025-11-14 21:02:21,635 - prediction_market - INFO - OptunaLightGBMTuner initialized (config_section=tuning)
# 2025-11-14 21:02:21,635 - prediction_market - INFO - Trials: 1, Timeout: None, Jobs: 1
# 2025-11-14 21:02:21,636 - prediction_market - INFO -
# 4.1 Running Optuna optimization (1 trials)...
# 2025-11-14 21:02:21,636 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:21,637 - prediction_market - INFO - Starting Hyperparameter Optimization
# 2025-11-14 21:02:21,637 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:21,637 - prediction_market - INFO -
# Features: 148
# 2025-11-14 21:02:21,637 - prediction_market - INFO - Samples: 9021
# 2025-11-14 21:02:21,638 - prediction_market - INFO - Target: forward_returns
# 2025-11-14 21:02:21,638 - prediction_market - INFO -
# Trials: 1
# 2025-11-14 21:02:21,639 - prediction_market - INFO - Timeout: None
# 2025-11-14 21:02:21,639 - prediction_market - INFO - Jobs: 1
# 2025-11-14 21:02:21,639 - prediction_market - INFO - Starting: Hyperparameter Optimization
# 2025-11-14 21:02:21,638 - prediction_market - INFO -
# Trials: 1
# 2025-11-14 21:02:21,639 - prediction_market - INFO - Timeout: None
# 2025-11-14 21:02:21,639 - prediction_market - INFO - Jobs: 1
# 2025-11-14 21:02:21,639 - prediction_market - INFO - Starting: Hyperparameter Optimization
# [I 2025-11-14 21:02:21,648] A new study created in memory with name: return_lgbm_tuning
# [I 2025-11-14 21:02:21,648] A new study created in memory with name: return_lgbm_tuning
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-11-14 21:02:21,689 - prediction_market - INFO - Starting Purged Walk-Forward CV with 5 splits
# 2025-11-14 21:02:21,690 - prediction_market - INFO - Total dates: 9021, Fold size: 1804
# 2025-11-14 21:02:21,690 - prediction_market - INFO - Embargo: 5, Purge: True, Purge period: 15, Train ratio: 0.8
# 2025-11-14 21:02:21,691 - prediction_market - INFO - Fold 1/5: Train dates: 1789 (0 to 1788), Val dates: 1804 (1804 to 3607), Train samples: 1789, Val samples: 1804, Purged: 15 dates from train end, Embargo: 5 dates
# 2025-11-14 21:02:21,692 - prediction_market - INFO - Fold 2/5: Train dates: 3593 (0 to 3592), Val dates: 1804 (3608 to 5411), Train samples: 3593, Val samples: 1804, Purged: 15 dates from train end, Embargo: 5 dates
# 2025-11-14 21:02:21,693 - prediction_market - INFO - Fold 3/5: Train dates: 5397 (0 to 5396), Val dates: 1804 (5412 to 7215), Train samples: 5397, Val samples: 1804, Purged: 15 dates from train end, Embargo: 5 dates
# 2025-11-14 21:02:21,693 - prediction_market - INFO - Fold 4/5: Train dates: 7201 (0 to 7200), Val dates: 1804 (7216 to 9019), Train samples: 7201, Val samples: 1804, Purged: 15 dates from train end, Embargo: 1 dates
# 2025-11-14 21:02:21,690 - prediction_market - INFO - Total dates: 9021, Fold size: 1804
# 2025-11-14 21:02:21,690 - prediction_market - INFO - Embargo: 5, Purge: True, Purge period: 15, Train ratio: 0.8
# 2025-11-14 21:02:21,691 - prediction_market - INFO - Fold 1/5: Train dates: 1789 (0 to 1788), Val dates: 1804 (1804 to 3607), Train samples: 1789, Val samples: 1804, Purged: 15 dates from train end, Embargo: 5 dates
# 2025-11-14 21:02:21,692 - prediction_market - INFO - Fold 2/5: Train dates: 3593 (0 to 3592), Val dates: 1804 (3608 to 5411), Train samples: 3593, Val samples: 1804, Purged: 15 dates from train end, Embargo: 5 dates
# 2025-11-14 21:02:21,693 - prediction_market - INFO - Fold 3/5: Train dates: 5397 (0 to 5396), Val dates: 1804 (5412 to 7215), Train samples: 5397, Val samples: 1804, Purged: 15 dates from train end, Embargo: 5 dates
# 2025-11-14 21:02:21,693 - prediction_market - INFO - Fold 4/5: Train dates: 7201 (0 to 7200), Val dates: 1804 (7216 to 9019), Train samples: 7201, Val samples: 1804, Purged: 15 dates from train end, Embargo: 1 dates
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# 2025-11-14 21:02:22,233 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:02:22,233 - prediction_market - INFO - Optimization Results
# 2025-11-14 21:02:22,233 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:22,234 - prediction_market - INFO -
# Best Score (RMSE): 0.011077
# 2025-11-14 21:02:22,235 - prediction_market - INFO - Best Trial: 0
# 2025-11-14 21:02:22,235 - prediction_market - INFO -
# Best Parameters:
# 2025-11-14 21:02:22,235 - prediction_market - INFO -   num_leaves: 50
# 2025-11-14 21:02:22,236 - prediction_market - INFO -   learning_rate: 0.2536999076681771
# 2025-11-14 21:02:22,236 - prediction_market - INFO -   feature_fraction: 0.8927975767245621
# 2025-11-14 21:02:22,236 - prediction_market - INFO -   bagging_fraction: 0.8394633936788146
# 2025-11-14 21:02:22,237 - prediction_market - INFO -   bagging_freq: 2
# 2025-11-14 21:02:22,238 - prediction_market - INFO -   min_child_samples: 24
# 2025-11-14 21:02:22,238 - prediction_market - INFO -   max_depth: 3
# 2025-11-14 21:02:22,239 - prediction_market - INFO -   reg_alpha: 0.6245760287469887
# 2025-11-14 21:02:22,240 - prediction_market - INFO -   reg_lambda: 0.002570603566117596
# 2025-11-14 21:02:22,240 - prediction_market - INFO - Completed: Hyperparameter Optimization - Time: 0.60s
# 2025-11-14 21:02:22,241 - prediction_market - INFO -
# ✓ Hyperparameter tuning complete
# 2025-11-14 21:02:22,241 - prediction_market - INFO -   Best score: 0.011077
# 2025-11-14 21:02:22,242 - prediction_market - INFO -   Best params:
# 2025-11-14 21:02:22,242 - prediction_market - INFO -     num_leaves: 50
# 2025-11-14 21:02:22,242 - prediction_market - INFO -     learning_rate: 0.2536999076681771
# 2025-11-14 21:02:22,243 - prediction_market - INFO -     feature_fraction: 0.8927975767245621
# 2025-11-14 21:02:22,243 - prediction_market - INFO -     bagging_fraction: 0.8394633936788146
# 2025-11-14 21:02:22,233 - prediction_market - INFO - Optimization Results
# 2025-11-14 21:02:22,233 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:22,234 - prediction_market - INFO -
# Best Score (RMSE): 0.011077
# 2025-11-14 21:02:22,235 - prediction_market - INFO - Best Trial: 0
# 2025-11-14 21:02:22,235 - prediction_market - INFO -
# Best Parameters:
# 2025-11-14 21:02:22,235 - prediction_market - INFO -   num_leaves: 50
# 2025-11-14 21:02:22,236 - prediction_market - INFO -   learning_rate: 0.2536999076681771
# 2025-11-14 21:02:22,236 - prediction_market - INFO -   feature_fraction: 0.8927975767245621
# 2025-11-14 21:02:22,236 - prediction_market - INFO -   bagging_fraction: 0.8394633936788146
# 2025-11-14 21:02:22,237 - prediction_market - INFO -   bagging_freq: 2
# 2025-11-14 21:02:22,238 - prediction_market - INFO -   min_child_samples: 24
# 2025-11-14 21:02:22,238 - prediction_market - INFO -   max_depth: 3
# 2025-11-14 21:02:22,239 - prediction_market - INFO -   reg_alpha: 0.6245760287469887
# 2025-11-14 21:02:22,240 - prediction_market - INFO -   reg_lambda: 0.002570603566117596
# 2025-11-14 21:02:22,240 - prediction_market - INFO - Completed: Hyperparameter Optimization - Time: 0.60s
# 2025-11-14 21:02:22,241 - prediction_market - INFO -
# ✓ Hyperparameter tuning complete
# 2025-11-14 21:02:22,241 - prediction_market - INFO -   Best score: 0.011077
# 2025-11-14 21:02:22,242 - prediction_market - INFO -   Best params:
# 2025-11-14 21:02:22,242 - prediction_market - INFO -     num_leaves: 50
# 2025-11-14 21:02:22,242 - prediction_market - INFO -     learning_rate: 0.2536999076681771
# 2025-11-14 21:02:22,243 - prediction_market - INFO -     feature_fraction: 0.8927975767245621
# 2025-11-14 21:02:22,243 - prediction_market - INFO -     bagging_fraction: 0.8394633936788146
# 2025-11-14 21:02:22,243 - prediction_market - INFO -     bagging_freq: 2
# 2025-11-14 21:02:22,244 - prediction_market - INFO -     min_child_samples: 24
# 2025-11-14 21:02:22,244 - prediction_market - INFO -     max_depth: 3
# 2025-11-14 21:02:22,244 - prediction_market - INFO -     reg_alpha: 0.6245760287469887
# 2025-11-14 21:02:22,244 - prediction_market - INFO -     reg_lambda: 0.002570603566117596
# 2025-11-14 21:02:22,245 - prediction_market - INFO - Completed: Hyperparameter Tuning - Time: 0.63s
# 2025-11-14 21:02:22,246 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:02:22,247 - prediction_market - INFO - STEP 5: FINAL MODEL TRAINING
# 2025-11-14 21:02:22,248 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:22,248 - prediction_market - INFO - Starting: Final Model Training
# 2025-11-14 21:02:22,243 - prediction_market - INFO -     bagging_freq: 2
# 2025-11-14 21:02:22,244 - prediction_market - INFO -     min_child_samples: 24
# 2025-11-14 21:02:22,244 - prediction_market - INFO -     max_depth: 3
# 2025-11-14 21:02:22,244 - prediction_market - INFO -     reg_alpha: 0.6245760287469887
# 2025-11-14 21:02:22,244 - prediction_market - INFO -     reg_lambda: 0.002570603566117596
# 2025-11-14 21:02:22,245 - prediction_market - INFO - Completed: Hyperparameter Tuning - Time: 0.63s
# 2025-11-14 21:02:22,246 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:02:22,247 - prediction_market - INFO - STEP 5: FINAL MODEL TRAINING
# 2025-11-14 21:02:22,248 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:22,248 - prediction_market - INFO - Starting: Final Model Training
# Early stopping, best iteration is:
# [2]	valid_0's rmse: 0.00880815
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	valid_0's rmse: 0.0110971
# [I 2025-11-14 21:02:22,231] Trial 0 finished with value: 0.011077353552166366 and parameters: {'num_leaves': 50, 'learning_rate': 0.2536999076681771, 'feature_fraction': 0.8927975767245621, 'bagging_fraction': 0.8394633936788146, 'bagging_freq': 2, 'min_child_samples': 24, 'max_depth': 3, 'reg_alpha': 0.6245760287469887, 'reg_lambda': 0.002570603566117596}. Best is trial 0 with value: 0.011077353552166366.
# 2025-11-14 21:02:22,329 - prediction_market - INFO - CV Strategy initialized
# 2025-11-14 21:02:22,334 - prediction_market - INFO - Configuration: {'n_splits': 5, 'embargo': 5, 'purge': True, 'purge_period': 15, 'train_ratio': 0.8}
# 2025-11-14 21:02:22,334 - prediction_market - INFO - ReturnPredictor initialized with lightgbm
# 2025-11-14 21:02:22,335 - prediction_market - INFO - Model params: {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'num_leaves': 31, 'learning_rate': 0.05, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'max_depth': -1, 'min_child_samples': 20, 'n_estimators': 1000, 'random_state': 42, 'verbosity': -1, 'early_stopping_rounds': 50, 'device_type': 'cpu', 'device': 'cpu'}
# 2025-11-14 21:02:22,335 - prediction_market - INFO -
# 5.1 Training with cross-validation...
# 2025-11-14 21:02:22,336 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:22,336 - prediction_market - INFO - Starting Cross-Validation Training
# 2025-11-14 21:02:22,337 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:22,340 - prediction_market - INFO -
# Features: 148
# 2025-11-14 21:02:22,340 - prediction_market - INFO - Samples: 9021
# 2025-11-14 21:02:22,340 - prediction_market - INFO - Date range: 0 to 9020
# 2025-11-14 21:02:22,342 - prediction_market - INFO - Starting Purged Walk-Forward CV with 5 splits
# 2025-11-14 21:02:22,343 - prediction_market - INFO - Total dates: 9021, Fold size: 1804
# 2025-11-14 21:02:22,343 - prediction_market - INFO - Embargo: 5, Purge: True, Purge period: 15, Train ratio: 0.8
# 2025-11-14 21:02:22,334 - prediction_market - INFO - Configuration: {'n_splits': 5, 'embargo': 5, 'purge': True, 'purge_period': 15, 'train_ratio': 0.8}
# 2025-11-14 21:02:22,334 - prediction_market - INFO - ReturnPredictor initialized with lightgbm
# 2025-11-14 21:02:22,335 - prediction_market - INFO - Model params: {'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'rmse', 'num_leaves': 31, 'learning_rate': 0.05, 'feature_fraction': 0.8, 'bagging_fraction': 0.8, 'bagging_freq': 5, 'max_depth': -1, 'min_child_samples': 20, 'n_estimators': 1000, 'random_state': 42, 'verbosity': -1, 'early_stopping_rounds': 50, 'device_type': 'cpu', 'device': 'cpu'}
# 2025-11-14 21:02:22,335 - prediction_market - INFO -
# 5.1 Training with cross-validation...
# 2025-11-14 21:02:22,336 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:22,336 - prediction_market - INFO - Starting Cross-Validation Training
# 2025-11-14 21:02:22,337 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:22,340 - prediction_market - INFO -
# Features: 148
# 2025-11-14 21:02:22,340 - prediction_market - INFO - Samples: 9021
# 2025-11-14 21:02:22,340 - prediction_market - INFO - Date range: 0 to 9020
# 2025-11-14 21:02:22,342 - prediction_market - INFO - Starting Purged Walk-Forward CV with 5 splits
# 2025-11-14 21:02:22,343 - prediction_market - INFO - Total dates: 9021, Fold size: 1804
# 2025-11-14 21:02:22,343 - prediction_market - INFO - Embargo: 5, Purge: True, Purge period: 15, Train ratio: 0.8
# 2025-11-14 21:02:22,344 - prediction_market - INFO - Fold 1/5: Train dates: 1789 (0 to 1788), Val dates: 1804 (1804 to 3607), Train samples: 1789, Val samples: 1804, Purged: 15 dates from train end, Embargo: 5 dates
# 2025-11-14 21:02:22,345 - prediction_market - INFO - Fold 2/5: Train dates: 3593 (0 to 3592), Val dates: 1804 (3608 to 5411), Train samples: 3593, Val samples: 1804, Purged: 15 dates from train end, Embargo: 5 dates
# 2025-11-14 21:02:22,346 - prediction_market - INFO - Fold 3/5: Train dates: 5397 (0 to 5396), Val dates: 1804 (5412 to 7215), Train samples: 5397, Val samples: 1804, Purged: 15 dates from train end, Embargo: 5 dates
# 2025-11-14 21:02:22,347 - prediction_market - INFO - Fold 4/5: Train dates: 7201 (0 to 7200), Val dates: 1804 (7216 to 9019), Train samples: 7201, Val samples: 1804, Purged: 15 dates from train end, Embargo: 1 dates
# 2025-11-14 21:02:22,351 - prediction_market - INFO -
# ============================================================
# 2025-11-14 21:02:22,351 - prediction_market - INFO - Fold 1
# 2025-11-14 21:02:22,352 - prediction_market - INFO - ============================================================
# 2025-11-14 21:02:22,353 - prediction_market - INFO - Train samples: 1789
# 2025-11-14 21:02:22,353 - prediction_market - INFO - Val samples: 1804
# 2025-11-14 21:02:22,354 - prediction_market - INFO - Starting: Training LGBM Fold 1
# 2025-11-14 21:02:22,344 - prediction_market - INFO - Fold 1/5: Train dates: 1789 (0 to 1788), Val dates: 1804 (1804 to 3607), Train samples: 1789, Val samples: 1804, Purged: 15 dates from train end, Embargo: 5 dates
# 2025-11-14 21:02:22,345 - prediction_market - INFO - Fold 2/5: Train dates: 3593 (0 to 3592), Val dates: 1804 (3608 to 5411), Train samples: 3593, Val samples: 1804, Purged: 15 dates from train end, Embargo: 5 dates
# 2025-11-14 21:02:22,346 - prediction_market - INFO - Fold 3/5: Train dates: 5397 (0 to 5396), Val dates: 1804 (5412 to 7215), Train samples: 5397, Val samples: 1804, Purged: 15 dates from train end, Embargo: 5 dates
# 2025-11-14 21:02:22,347 - prediction_market - INFO - Fold 4/5: Train dates: 7201 (0 to 7200), Val dates: 1804 (7216 to 9019), Train samples: 7201, Val samples: 1804, Purged: 15 dates from train end, Embargo: 1 dates
# 2025-11-14 21:02:22,351 - prediction_market - INFO -
# ============================================================
# 2025-11-14 21:02:22,351 - prediction_market - INFO - Fold 1
# 2025-11-14 21:02:22,352 - prediction_market - INFO - ============================================================
# 2025-11-14 21:02:22,353 - prediction_market - INFO - Train samples: 1789
# 2025-11-14 21:02:22,353 - prediction_market - INFO - Val samples: 1804
# 2025-11-14 21:02:22,354 - prediction_market - INFO - Starting: Training LGBM Fold 1
# 2025-11-14 21:02:22,409 - prediction_market - INFO - Completed: Training LGBM Fold 1 - Time: 0.06s
# 2025-11-14 21:02:22,410 - prediction_market - INFO - Fold 1 validation score: 0.012819
# 2025-11-14 21:02:22,412 - prediction_market - INFO -
# ============================================================
# 2025-11-14 21:02:22,412 - prediction_market - INFO - Fold 2
# 2025-11-14 21:02:22,413 - prediction_market - INFO - ============================================================
# 2025-11-14 21:02:22,413 - prediction_market - INFO - Train samples: 3593
# 2025-11-14 21:02:22,413 - prediction_market - INFO - Val samples: 1804
# 2025-11-14 21:02:22,413 - prediction_market - INFO - Starting: Training LGBM Fold 2
# 2025-11-14 21:02:22,409 - prediction_market - INFO - Completed: Training LGBM Fold 1 - Time: 0.06s
# 2025-11-14 21:02:22,410 - prediction_market - INFO - Fold 1 validation score: 0.012819
# 2025-11-14 21:02:22,412 - prediction_market - INFO -
# ============================================================
# 2025-11-14 21:02:22,412 - prediction_market - INFO - Fold 2
# 2025-11-14 21:02:22,413 - prediction_market - INFO - ============================================================
# 2025-11-14 21:02:22,413 - prediction_market - INFO - Train samples: 3593
# 2025-11-14 21:02:22,413 - prediction_market - INFO - Val samples: 1804
# 2025-11-14 21:02:22,413 - prediction_market - INFO - Starting: Training LGBM Fold 2
# ...
# 2025-11-14 21:02:22,763 - prediction_market - INFO -   E12_lag_3: 0.00
# 2025-11-14 21:02:22,763 - prediction_market - INFO -
# ✓ Final model training complete
# 2025-11-14 21:02:22,763 - prediction_market - INFO -   OOF Score: 0.011172
# 2025-11-14 21:02:22,764 - prediction_market - INFO -   Number of models: 4
# 2025-11-14 21:02:22,767 - prediction_market - INFO - Model fold 0 saved to artifacts/models_optimized/lightgbm_fold_0.pkl
# 2025-11-14 21:02:22,768 - prediction_market - INFO - Model fold 1 saved to artifacts/models_optimized/lightgbm_fold_1.pkl
# 2025-11-14 21:02:22,769 - prediction_market - INFO - Model fold 2 saved to artifacts/models_optimized/lightgbm_fold_2.pkl
# 2025-11-14 21:02:22,769 - prediction_market - INFO - Model fold 3 saved to artifacts/models_optimized/lightgbm_fold_3.pkl
# 2025-11-14 21:02:22,759 - prediction_market - INFO -   V7: 0.00
# 2025-11-14 21:02:22,759 - prediction_market - INFO -   P8_pct_1: 0.00
# 2025-11-14 21:02:22,760 - prediction_market - INFO -   M4_zscore_10: 0.00
# 2025-11-14 21:02:22,760 - prediction_market - INFO -   M17_roll_min_60: 0.00
# 2025-11-14 21:02:22,760 - prediction_market - INFO -   P2_diff_1: 0.00
# 2025-11-14 21:02:22,760 - prediction_market - INFO -   M4_roll_min_5: 0.00
# 2025-11-14 21:02:22,761 - prediction_market - INFO -   M9_roll_std_5: 0.00
# 2025-11-14 21:02:22,761 - prediction_market - INFO -   M10_zscore_10: 0.00
# 2025-11-14 21:02:22,762 - prediction_market - INFO -   P7: 0.00
# 2025-11-14 21:02:22,762 - prediction_market - INFO -   M11_zscore_60: 0.00
# 2025-11-14 21:02:22,763 - prediction_market - INFO -   E12_lag_3: 0.00
# 2025-11-14 21:02:22,763 - prediction_market - INFO -
# ✓ Final model training complete
# 2025-11-14 21:02:22,763 - prediction_market - INFO -   OOF Score: 0.011172
# 2025-11-14 21:02:22,764 - prediction_market - INFO -   Number of models: 4
# 2025-11-14 21:02:22,767 - prediction_market - INFO - Model fold 0 saved to artifacts/models_optimized/lightgbm_fold_0.pkl
# 2025-11-14 21:02:22,768 - prediction_market - INFO - Model fold 1 saved to artifacts/models_optimized/lightgbm_fold_1.pkl
# 2025-11-14 21:02:22,769 - prediction_market - INFO - Model fold 2 saved to artifacts/models_optimized/lightgbm_fold_2.pkl
# 2025-11-14 21:02:22,769 - prediction_market - INFO - Model fold 3 saved to artifacts/models_optimized/lightgbm_fold_3.pkl
# 2025-11-14 21:02:22,771 - prediction_market - INFO - Feature importance saved to artifacts/models_optimized/lightgbm_feature_importance.csv
# 2025-11-14 21:02:22,773 - prediction_market - INFO -
# ✓ OOF predictions saved to artifacts/oof_return_predictions.npy
# 2025-11-14 21:02:22,773 - prediction_market - INFO - Completed: Final Model Training - Time: 0.52s
# 2025-11-14 21:02:22,774 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:02:22,774 - prediction_market - INFO - STEP 6: MODEL INTERPRETATION
# 2025-11-14 21:02:22,775 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:22,776 - prediction_market - INFO - Starting: Model Interpretation
# 2025-11-14 21:02:22,776 - prediction_market - INFO - ModelInterpreter initialized
# 2025-11-14 21:02:22,776 - prediction_market - INFO - Models: 4, Features: 148
# 2025-11-14 21:02:22,777 - prediction_market - INFO -
# 6.1 Calculating feature importance...
# 2025-11-14 21:02:22,778 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:22,779 - prediction_market - INFO - Calculating Feature Importance
# 2025-11-14 21:02:22,779 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:22,779 - prediction_market - INFO - Importance type: gain
# 2025-11-14 21:02:22,779 - prediction_market - INFO - Starting: Feature Importance Calculation
# 2025-11-14 21:02:22,780 - prediction_market - INFO - Feature names: 148
# 2025-11-14 21:02:22,780 - prediction_market - INFO - Avg importance: 148
# 2025-11-14 21:02:22,781 - prediction_market - INFO - Std importance: 148
# 2025-11-14 21:02:22,782 - prediction_market - INFO -
# Top 20 Features by gain:
# 2025-11-14 21:02:22,782 - prediction_market - INFO -    1. M9_dev_10                     : 0.0007 (±0.0007)
# 2025-11-14 21:02:22,782 - prediction_market - INFO -    2. M11_roll_std_40               : 0.0005 (±0.0005)
# 2025-11-14 21:02:22,783 - prediction_market - INFO -    3. E9_lag_3                      : 0.0005 (±0.0009)
# 2025-11-14 21:02:22,783 - prediction_market - INFO -    4. M4_lag_2                      : 0.0005 (±0.0005)
# 2025-11-14 21:02:22,783 - prediction_market - INFO -    5. M9_accel                      : 0.0004 (±0.0004)
# 2025-11-14 21:02:22,784 - prediction_market - INFO -    6. I2                            : 0.0004 (±0.0004)
# 2025-11-14 21:02:22,784 - prediction_market - INFO -    7. M3_zscore_5                   : 0.0003 (±0.0005)
# 2025-11-14 21:02:22,784 - prediction_market - INFO -    8. M9_zscore_5                   : 0.0002 (±0.0003)
# 2025-11-14 21:02:22,785 - prediction_market - INFO -    9. P8_diff_1                     : 0.0002 (±0.0004)
# 2025-11-14 21:02:22,771 - prediction_market - INFO - Feature importance saved to artifacts/models_optimized/lightgbm_feature_importance.csv
# 2025-11-14 21:02:22,773 - prediction_market - INFO -
# ✓ OOF predictions saved to artifacts/oof_return_predictions.npy
# 2025-11-14 21:02:22,773 - prediction_market - INFO - Completed: Final Model Training - Time: 0.52s
# 2025-11-14 21:02:22,774 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:02:22,774 - prediction_market - INFO - STEP 6: MODEL INTERPRETATION
# 2025-11-14 21:02:22,775 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:22,776 - prediction_market - INFO - Starting: Model Interpretation
# 2025-11-14 21:02:22,776 - prediction_market - INFO - ModelInterpreter initialized
# 2025-11-14 21:02:22,776 - prediction_market - INFO - Models: 4, Features: 148
# 2025-11-14 21:02:22,777 - prediction_market - INFO -
# 6.1 Calculating feature importance...
# 2025-11-14 21:02:22,778 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:22,779 - prediction_market - INFO - Calculating Feature Importance
# 2025-11-14 21:02:22,779 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:22,779 - prediction_market - INFO - Importance type: gain
# 2025-11-14 21:02:22,779 - prediction_market - INFO - Starting: Feature Importance Calculation
# 2025-11-14 21:02:22,780 - prediction_market - INFO - Feature names: 148
# 2025-11-14 21:02:22,780 - prediction_market - INFO - Avg importance: 148
# 2025-11-14 21:02:22,781 - prediction_market - INFO - Std importance: 148
# 2025-11-14 21:02:22,782 - prediction_market - INFO -
# Top 20 Features by gain:
# 2025-11-14 21:02:22,782 - prediction_market - INFO -    1. M9_dev_10                     : 0.0007 (±0.0007)
# 2025-11-14 21:02:22,782 - prediction_market - INFO -    2. M11_roll_std_40               : 0.0005 (±0.0005)
# 2025-11-14 21:02:22,783 - prediction_market - INFO -    3. E9_lag_3                      : 0.0005 (±0.0009)
# 2025-11-14 21:02:22,783 - prediction_market - INFO -    4. M4_lag_2                      : 0.0005 (±0.0005)
# 2025-11-14 21:02:22,783 - prediction_market - INFO -    5. M9_accel                      : 0.0004 (±0.0004)
# 2025-11-14 21:02:22,784 - prediction_market - INFO -    6. I2                            : 0.0004 (±0.0004)
# 2025-11-14 21:02:22,784 - prediction_market - INFO -    7. M3_zscore_5                   : 0.0003 (±0.0005)
# 2025-11-14 21:02:22,784 - prediction_market - INFO -    8. M9_zscore_5                   : 0.0002 (±0.0003)
# 2025-11-14 21:02:22,785 - prediction_market - INFO -    9. P8_diff_1                     : 0.0002 (±0.0004)
# 2025-11-14 21:02:22,785 - prediction_market - INFO -   10. V7                            : 0.0002 (±0.0003)
# 2025-11-14 21:02:22,785 - prediction_market - INFO -   11. P8_pct_1                      : 0.0002 (±0.0003)
# 2025-11-14 21:02:22,786 - prediction_market - INFO -   12. M4_zscore_10                  : 0.0002 (±0.0003)
# 2025-11-14 21:02:22,786 - prediction_market - INFO -   13. M17_roll_min_60               : 0.0002 (±0.0003)
# 2025-11-14 21:02:22,786 - prediction_market - INFO -   14. P2_diff_1                     : 0.0002 (±0.0003)
# 2025-11-14 21:02:22,786 - prediction_market - INFO -   15. M4_roll_min_5                 : 0.0001 (±0.0002)
# 2025-11-14 21:02:22,786 - prediction_market - INFO -   16. M9_roll_std_5                 : 0.0001 (±0.0002)
# 2025-11-14 21:02:22,787 - prediction_market - INFO -   17. M10_zscore_10                 : 0.0001 (±0.0001)
# 2025-11-14 21:02:22,788 - prediction_market - INFO -   18. P7                            : 0.0000 (±0.0000)
# 2025-11-14 21:02:22,789 - prediction_market - INFO -   19. M11_zscore_60                 : 0.0000 (±0.0000)
# 2025-11-14 21:02:22,790 - prediction_market - INFO -   20. E12_lag_3                     : 0.0000 (±0.0000)
# 2025-11-14 21:02:22,790 - prediction_market - INFO - Completed: Feature Importance Calculation - Time: 0.01s
# 2025-11-14 21:02:22,791 - prediction_market - INFO -
# 6.2 Calculating SHAP values...
# 2025-11-14 21:02:22,795 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:22,785 - prediction_market - INFO -   10. V7                            : 0.0002 (±0.0003)
# 2025-11-14 21:02:22,785 - prediction_market - INFO -   11. P8_pct_1                      : 0.0002 (±0.0003)
# 2025-11-14 21:02:22,786 - prediction_market - INFO -   12. M4_zscore_10                  : 0.0002 (±0.0003)
# 2025-11-14 21:02:22,786 - prediction_market - INFO -   13. M17_roll_min_60               : 0.0002 (±0.0003)
# 2025-11-14 21:02:22,786 - prediction_market - INFO -   14. P2_diff_1                     : 0.0002 (±0.0003)
# 2025-11-14 21:02:22,786 - prediction_market - INFO -   15. M4_roll_min_5                 : 0.0001 (±0.0002)
# 2025-11-14 21:02:22,786 - prediction_market - INFO -   16. M9_roll_std_5                 : 0.0001 (±0.0002)
# 2025-11-14 21:02:22,787 - prediction_market - INFO -   17. M10_zscore_10                 : 0.0001 (±0.0001)
# 2025-11-14 21:02:22,788 - prediction_market - INFO -   18. P7                            : 0.0000 (±0.0000)
# 2025-11-14 21:02:22,789 - prediction_market - INFO -   19. M11_zscore_60                 : 0.0000 (±0.0000)
# 2025-11-14 21:02:22,790 - prediction_market - INFO -   20. E12_lag_3                     : 0.0000 (±0.0000)
# 2025-11-14 21:02:22,790 - prediction_market - INFO - Completed: Feature Importance Calculation - Time: 0.01s
# 2025-11-14 21:02:22,791 - prediction_market - INFO -
# 6.2 Calculating SHAP values...
# 2025-11-14 21:02:22,795 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:22,796 - prediction_market - INFO - Calculating SHAP Values
# 2025-11-14 21:02:22,796 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:22,797 - prediction_market - INFO - Samples: 1000
# 2025-11-14 21:02:22,797 - prediction_market - INFO - Features: 148
# 2025-11-14 21:02:22,796 - prediction_market - INFO - Calculating SHAP Values
# 2025-11-14 21:02:22,796 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:02:22,797 - prediction_market - INFO - Samples: 1000
# 2025-11-14 21:02:22,797 - prediction_market - INFO - Features: 148
# 2025-11-14 21:02:22,797 - prediction_market - INFO - Starting: SHAP Values Calculation
# 2025-11-14 21:02:22,798 - prediction_market - ERROR - SHAP library not installed. Install with: pip install shap
# 2025-11-14 21:02:22,799 - prediction_market - INFO - Completed: SHAP Values Calculation - Time: 0.00s
# 2025-11-14 21:02:22,797 - prediction_market - INFO - Starting: SHAP Values Calculation
# 2025-11-14 21:02:22,798 - prediction_market - ERROR - SHAP library not installed. Install with: pip install shap
# 2025-11-14 21:02:22,799 - prediction_market - INFO - Completed: SHAP Values Calculation - Time: 0.00s
# 2025-11-14 21:02:22,799 - prediction_market - INFO - Completed: Model Interpretation - Time: 0.02s
# 2025-11-14 21:02:22,799 - prediction_market - INFO - Completed: Model Interpretation - Time: 0.02s
# Early stopping, best iteration is:
# [2]	train's rmse: 0.0108178	valid's rmse: 0.00880815
# Training until validation scores don't improve for 50 rounds
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/projects/hull_prediction_market/scripts/optimize_return_model.py:705
#     701     logger.info("\n✓ Optimization complete! Check results/ and artifacts/ directories.")
#     704 if __name__ == "__main__":
# --> 705     main()
#     708 """
#     709 # 최적화 결과 요약 확인
#     710 cat results/optimization/optimization_summary.json
#    (...)    722 ls -la artifacts/models_optimized/
#     723 """
#
# File ~/projects/hull_prediction_market/scripts/optimize_return_model.py:681, in main()
#     678 optimizer = ReturnModelOptimizer(config_path="conf/params.yaml")
#     680 # Run full optimization
# --> 681 results = optimizer.run_full_optimization(
#     682     # Preprocessing (data cleaning)
#     683     handle_outliers=True,
#     684     normalize=True,
#     685     scale=True,
#     686     # Feature Engineering (new features)
#     687     add_time_features=True,
#     688     add_regime_features=True,
#     689     # Feature Selection
#     690     selection_method='correlation',  # or 'mutual_info'
#     691     top_n_features=200,
#     692     remove_correlated=True,
#     693     corr_threshold=0.95,
#     694     # Hyperparameter Tuning
#     695     n_trials=1,  # Increase for better results
#     696     timeout=None,  # Or set time limit in seconds
#     697     # Interpretation
#     698     calculate_shap=True  # Set True for SHAP analysis (slow)
#     699 )
#     701 logger.info("\n✓ Optimization complete! Check results/ and artifacts/ directories.")
#
# File ~/projects/hull_prediction_market/scripts/optimize_return_model.py:657, in ReturnModelOptimizer.run_full_optimization(self, handle_outliers, normalize, scale, add_time_features, add_regime_features, selection_method, top_n_features, remove_correlated, corr_threshold, n_trials, timeout, calculate_shap)
#     650 predictor, oof_preds, oof_score = self.step5_train_final_model(
#     651     train_selected,
#     652     selected_features,
#     653     best_params
#     654 )
#     656 # Step 6: Model interpretation
# --> 657 interpreter = self.step6_model_interpretation(
#     658     predictor,
#     659     train_selected,
#     660     selected_features,
#     661     calculate_shap=calculate_shap
#     662 )
#     664 # Step 7: Save results
#     665 self.step7_save_results()
#
# File ~/projects/hull_prediction_market/scripts/optimize_return_model.py:480, in ReturnModelOptimizer.step6_model_interpretation(self, predictor, df, feature_cols, calculate_shap)
#     478     logger.info("\n6.2 Calculating SHAP values...")
#     479     X = df[feature_cols].sample(n=1000, random_state=42)
# --> 480     shap_values = interpreter.calculate_shap_values(X, sample_size=1000)
#     482 # Save analysis
#     483 logger.info("\n6.3 Saving interpretability results...")
#
# File ~/projects/hull_prediction_market/src/interpretability.py:203, in ModelInterpreter.calculate_shap_values(self, X, sample_size, random_state)
#     201 with Timer("SHAP Values Calculation"):
#     202     try:
# --> 203         import shap
#     205         # Calculate SHAP values for each fold
#     206         shap_values_list = []
#
# ModuleNotFoundError: No module named 'shap'
# ✅ Return model training complete!
# 📊 Model saved to: artifacts/models_optimized/

# %% [markdown]
# ## 3️⃣ Step 2: Train Risk Model (~10 min)

# %%
print("="*80)
print("STEP 2/3: TRAINING RISK MODEL")
print("="*80)

# Risk model 학습 스크립트 실행
script_path = project_root / "scripts" / "optimize_risk_model.py"

if script_path.exists():
    print(f"▶ Running: {script_path.name}\n")
    
    # 현재 디렉토리를 프로젝트 루트로 변경
    original_cwd = os.getcwd()
    os.chdir(project_root)
    
    # %run {script_path}
    
    # 원래 디렉토리로 복귀
    os.chdir(original_cwd)
    
    print("\n✅ Risk model training complete!")
    print(f"📊 Model saved to: artifacts/models_risk_optimized/")
else:
    raise FileNotFoundError(f"Script not found: {script_path}")
# Out:
# 2025-11-14 21:00:03,673 - prediction_market - INFO - Feature Engineering initialized
# 2025-11-14 21:00:03,673 - prediction_market - INFO - Rolling windows: [5, 10, 20, 40, 60]
# 2025-11-14 21:00:03,673 - prediction_market - INFO - Lag periods: [1, 2, 3, 5, 10]
# 2025-11-14 21:00:03,674 - prediction_market - INFO - Scaler type: robust
# 2025-11-14 21:00:03,682 - prediction_market - INFO - RiskLabeler initialized
# 2025-11-14 21:00:03,682 - prediction_market - INFO - Window: 20, Min periods: 10
# 2025-11-14 21:00:03,682 - prediction_market - INFO - Clip threshold: 4.0 MAD
# 2025-11-14 21:00:03,683 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,683 - prediction_market - INFO - RISK MODEL OPTIMIZATION PIPELINE
# 2025-11-14 21:00:03,673 - prediction_market - INFO - Rolling windows: [5, 10, 20, 40, 60]
# 2025-11-14 21:00:03,673 - prediction_market - INFO - Lag periods: [1, 2, 3, 5, 10]
# 2025-11-14 21:00:03,674 - prediction_market - INFO - Scaler type: robust
# 2025-11-14 21:00:03,682 - prediction_market - INFO - RiskLabeler initialized
# 2025-11-14 21:00:03,682 - prediction_market - INFO - Window: 20, Min periods: 10
# 2025-11-14 21:00:03,682 - prediction_market - INFO - Clip threshold: 4.0 MAD
# 2025-11-14 21:00:03,683 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,683 - prediction_market - INFO - RISK MODEL OPTIMIZATION PIPELINE
# 2025-11-14 21:00:03,684 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,684 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:00:03,684 - prediction_market - INFO - STARTING FULL RISK MODEL OPTIMIZATION PIPELINE
# 2025-11-14 21:00:03,685 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,685 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:00:03,686 - prediction_market - INFO - STEP 1: DATA LOADING AND PREPROCESSING
# 2025-11-14 21:00:03,686 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,687 - prediction_market - INFO - Starting: Data Loading and Preprocessing
# 2025-11-14 21:00:03,688 - prediction_market - INFO -
# 1.1 Loading raw data...
# 2025-11-14 21:00:03,688 - prediction_market - INFO - Starting: Loading data
# 2025-11-14 21:00:03,689 - prediction_market - INFO - Loading train data from data/raw/train.csv
# 2025-11-14 21:00:03,689 - prediction_market - INFO - Completed: Loading data - Time: 0.00s
# 2025-11-14 21:00:03,689 - prediction_market - INFO - Completed: Data Loading and Preprocessing - Time: 0.00s
# 2025-11-14 21:00:03,684 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,684 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:00:03,684 - prediction_market - INFO - STARTING FULL RISK MODEL OPTIMIZATION PIPELINE
# 2025-11-14 21:00:03,685 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,685 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:00:03,686 - prediction_market - INFO - STEP 1: DATA LOADING AND PREPROCESSING
# 2025-11-14 21:00:03,686 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,687 - prediction_market - INFO - Starting: Data Loading and Preprocessing
# 2025-11-14 21:00:03,688 - prediction_market - INFO -
# 1.1 Loading raw data...
# 2025-11-14 21:00:03,688 - prediction_market - INFO - Starting: Loading data
# 2025-11-14 21:00:03,689 - prediction_market - INFO - Loading train data from data/raw/train.csv
# 2025-11-14 21:00:03,689 - prediction_market - INFO - Completed: Loading data - Time: 0.00s
# 2025-11-14 21:00:03,689 - prediction_market - INFO - Completed: Data Loading and Preprocessing - Time: 0.00s
# ================================================================================
# STEP 2/3: TRAINING RISK MODEL
# ================================================================================
# ▶ Running: optimize_risk_model.py
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/projects/hull_prediction_market/scripts/optimize_risk_model.py:794
#     790     logger.info("\n✓ Risk model optimization complete! Check results/ and artifacts/ directories.")
#     793 if __name__ == "__main__":
# --> 794     main()
#
# File ~/projects/hull_prediction_market/scripts/optimize_risk_model.py:770, in main()
#     767 optimizer = RiskModelOptimizer(config_path="conf/params.yaml")
#     769 # Run full optimization
# --> 770 results = optimizer.run_full_optimization(
#     771     # Preprocessing (data cleaning)
#     772     handle_outliers=True,
#     773     normalize=True,
#     774     scale=True,
#     775     # Feature Engineering (new features)
#     776     add_time_features=True,
#     777     add_regime_features=True,
#     778     # Feature Selection
#     779     selection_method='correlation',  # or 'mutual_info'
#     780     top_n_features=200,
#     781     remove_correlated=True,
#     782     corr_threshold=0.95,
#     783     # Hyperparameter Tuning
#     784     n_trials=1,  # Increase for better results
#     785     timeout=None,  # Or set time limit in seconds
#     786     # Interpretation
#     787     calculate_shap=False  # Set True for SHAP analysis (slow)
#     788 )
#     790 logger.info("\n✓ Risk model optimization complete! Check results/ and artifacts/ directories.")
#
# File ~/projects/hull_prediction_market/scripts/optimize_risk_model.py:705, in RiskModelOptimizer.run_full_optimization(self, handle_outliers, normalize, scale, add_time_features, add_regime_features, selection_method, top_n_features, remove_correlated, corr_threshold, n_trials, timeout, calculate_shap)
#     702 logger.info("="*80)
#     704 # Step 1: Load and preprocess data
# --> 705 train_df, metadata = self.step1_load_and_preprocess_data(
#     706     handle_outliers=handle_outliers,
#     707     normalize=normalize,
#     708     scale=scale
#     709 )
#     711 # Step 2: Feature engineering
#     712 train_engineered = self.step2_feature_engineering(
#     713     train_df,
#     714     add_time_features=add_time_features,
#     715     add_regime_features=add_regime_features
#     716 )
#
# File ~/projects/hull_prediction_market/scripts/optimize_risk_model.py:111, in RiskModelOptimizer.step1_load_and_preprocess_data(self, handle_outliers, normalize, scale)
#     108 with Timer("Data Loading and Preprocessing", logger):
#     109     # Load data
#     110     logger.info("\n1.1 Loading raw data...")
# --> 111     train_df, _ = self.data_loader.load_data()
#     112     logger.info(f"✓ Loaded {len(train_df)} samples")
#     114     # Preprocess (data cleaning only)
#
# File ~/projects/hull_prediction_market/src/data.py:75, in DataLoader.load_data(self, train_path, test_path)
#      72 test_path = test_path or self.data_dir / 'test.csv'
#      74 logger.info(f"Loading train data from {train_path}")
# ---> 75 self.train_df = pd.read_csv(train_path)
#      77 logger.info(f"Loading test data from {test_path}")
#      78 self.test_df = pd.read_csv(test_path)
#
# File ~/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/raw/train.csv'
# ✅ Risk model training complete!
# 📊 Model saved to: artifacts/models_risk_optimized/

# %% [markdown]
# ## 4️⃣ Step 3: Optimize Position Strategy (~10 min)

# %%
print("="*80)
print("STEP 3/3: OPTIMIZING POSITION STRATEGY")
print("="*80)

# Position strategy 최적화 스크립트 실행
script_path = project_root / "scripts" / "optimize_position_strategy.py"

if script_path.exists():
    print(f"▶ Running: {script_path.name}\n")
    
    # 현재 디렉토리를 프로젝트 루트로 변경
    original_cwd = os.getcwd()
    os.chdir(project_root)
    
    # %run {script_path}
    
    # 원래 디렉토리로 복귀
    os.chdir(original_cwd)
    
    print("\n✅ Position strategy optimization complete!")
    print(f"📊 Strategy saved to: artifacts/position_strategy.json")
else:
    raise FileNotFoundError(f"Script not found: {script_path}")
# Out:
# ================================================================================
# STEP 3/3: OPTIMIZING POSITION STRATEGY
# ================================================================================
# ▶ Running: optimize_position_strategy.py
# 2025-11-14 21:00:03,852 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,853 - prediction_market - INFO - POSITION STRATEGY OPTIMIZATION
# 2025-11-14 21:00:03,853 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,853 - prediction_market - INFO - POSITION STRATEGY OPTIMIZATION
# 2025-11-14 21:00:03,853 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,880 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,881 - prediction_market - INFO - POSITION STRATEGY OPTIMIZATION PIPELINE
# 2025-11-14 21:00:03,881 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,881 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:00:03,881 - prediction_market - INFO - STARTING POSITION STRATEGY OPTIMIZATION
# 2025-11-14 21:00:03,882 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,880 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,881 - prediction_market - INFO - POSITION STRATEGY OPTIMIZATION PIPELINE
# 2025-11-14 21:00:03,881 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,881 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:00:03,881 - prediction_market - INFO - STARTING POSITION STRATEGY OPTIMIZATION
# 2025-11-14 21:00:03,882 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,883 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:00:03,884 - prediction_market - INFO - STEP 1: LOAD/GENERATE PREDICTIONS
# 2025-11-14 21:00:03,884 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,884 - prediction_market - INFO - Starting: Prediction Loading
# 2025-11-14 21:00:03,884 - prediction_market - INFO -
# 1.1 Loading training data...
# 2025-11-14 21:00:03,885 - prediction_market - INFO - Starting: Loading data
# 2025-11-14 21:00:03,885 - prediction_market - INFO - Loading train data from data/raw/train.csv
# 2025-11-14 21:00:03,885 - prediction_market - INFO - Completed: Loading data - Time: 0.00s
# 2025-11-14 21:00:03,885 - prediction_market - INFO - Completed: Prediction Loading - Time: 0.00s
# 2025-11-14 21:00:03,885 - prediction_market - ERROR - Optimization failed: [Errno 2] No such file or directory: 'data/raw/train.csv'
# Traceback (most recent call last):
#   File "/Users/gimjunseog/projects/hull_prediction_market/scripts/optimize_position_strategy.py", line 912, in run_full_optimization
#     train_df, r_hat, sigma_hat = self.step1_load_predictions(
#                                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         return_model_dir, risk_model_dir
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/gimjunseog/projects/hull_prediction_market/scripts/optimize_position_strategy.py", line 98, in step1_load_predictions
#     train_df, _ = self.data_loader.load_data()
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/Users/gimjunseog/projects/hull_prediction_market/src/data.py", line 75, in load_data
#     self.train_df = pd.read_csv(train_path)
#                     ~~~~~~~~~~~^^^^^^^^^^^^
#   File "/Users/gimjunseog/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/Users/gimjunseog/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py", line 620, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/Users/gimjunseog/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py", line 1620, in __init__
#     self._engine = self._make_engine(f, self.engine)
#                    ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "/Users/gimjunseog/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py", line 1880, in _make_engine
#     self.handles = get_handle(
#                    ~~~~~~~~~~^
#         f,
#         ^^
#     ...<6 lines>...
#         storage_options=self.options.get("storage_options", None),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/gimjunseog/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/common.py", line 873, in get_handle
#     handle = open(
#         handle,
#     ...<3 lines>...
#         newline="",
#     )
# FileNotFoundError: [Errno 2] No such file or directory: 'data/raw/train.csv'
# 2025-11-14 21:00:03,883 - prediction_market - INFO -
# ================================================================================
# 2025-11-14 21:00:03,884 - prediction_market - INFO - STEP 1: LOAD/GENERATE PREDICTIONS
# 2025-11-14 21:00:03,884 - prediction_market - INFO - ================================================================================
# 2025-11-14 21:00:03,884 - prediction_market - INFO - Starting: Prediction Loading
# 2025-11-14 21:00:03,884 - prediction_market - INFO -
# 1.1 Loading training data...
# 2025-11-14 21:00:03,885 - prediction_market - INFO - Starting: Loading data
# 2025-11-14 21:00:03,885 - prediction_market - INFO - Loading train data from data/raw/train.csv
# 2025-11-14 21:00:03,885 - prediction_market - INFO - Completed: Loading data - Time: 0.00s
# 2025-11-14 21:00:03,885 - prediction_market - INFO - Completed: Prediction Loading - Time: 0.00s
# 2025-11-14 21:00:03,885 - prediction_market - ERROR - Optimization failed: [Errno 2] No such file or directory: 'data/raw/train.csv'
# Traceback (most recent call last):
#   File "/Users/gimjunseog/projects/hull_prediction_market/scripts/optimize_position_strategy.py", line 912, in run_full_optimization
#     train_df, r_hat, sigma_hat = self.step1_load_predictions(
#                                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         return_model_dir, risk_model_dir
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/gimjunseog/projects/hull_prediction_market/scripts/optimize_position_strategy.py", line 98, in step1_load_predictions
#     train_df, _ = self.data_loader.load_data()
#                   ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/Users/gimjunseog/projects/hull_prediction_market/src/data.py", line 75, in load_data
#     self.train_df = pd.read_csv(train_path)
#                     ~~~~~~~~~~~^^^^^^^^^^^^
#   File "/Users/gimjunseog/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/Users/gimjunseog/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py", line 620, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/Users/gimjunseog/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py", line 1620, in __init__
#     self._engine = self._make_engine(f, self.engine)
#                    ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "/Users/gimjunseog/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py", line 1880, in _make_engine
#     self.handles = get_handle(
#                    ~~~~~~~~~~^
#         f,
#         ^^
#     ...<6 lines>...
#         storage_options=self.options.get("storage_options", None),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/Users/gimjunseog/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/common.py", line 873, in get_handle
#     handle = open(
#         handle,
#     ...<3 lines>...
#         newline="",
#     )
# FileNotFoundError: [Errno 2] No such file or directory: 'data/raw/train.csv'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/projects/hull_prediction_market/scripts/optimize_position_strategy.py:1019
#    1015         logger.info(f"✅ Submission file created: {results['test_predictions']['output_path']}")
#    1018 if __name__ == "__main__":
# -> 1019     main()
#
# File ~/projects/hull_prediction_market/scripts/optimize_position_strategy.py:1002, in main()
#     999 optimizer = PositionStrategyOptimizer(config_path="conf/params.yaml")
#    1001 # Run full optimization
# -> 1002 results = optimizer.run_full_optimization(
#    1003     return_model_dir="artifacts/models_optimized",
#    1004     risk_model_dir="artifacts/models_risk_optimized",
#    1005     n_trials_sharpe=100,      # Adjust based on time/resources
#    1006     n_trials_quantile=100,    # Adjust based on time/resources
#    1007     predict_test=True         # Generate submission.parquet
#    1008 )
#    1010 logger.info("\n✅ Position strategy optimization complete!")
#    1011 logger.info(f"Best strategy: {results['best_strategy']['strategy_name']}")
#
# File ~/projects/hull_prediction_market/scripts/optimize_position_strategy.py:912, in PositionStrategyOptimizer.run_full_optimization(self, return_model_dir, risk_model_dir, n_trials_sharpe, n_trials_quantile, predict_test)
#     908 start_time = pd.Timestamp.now()
#     910 try:
#     911     # Step 1: Load/generate predictions
# --> 912     train_df, r_hat, sigma_hat = self.step1_load_predictions(
#     913         return_model_dir, risk_model_dir
#     914     )
#     916     # Step 2: Optimize Sharpe Scaling
#     917     self.step2_optimize_sharpe_scaling(
#     918         train_df, r_hat, sigma_hat, n_trials=n_trials_sharpe
#     919     )
#
# File ~/projects/hull_prediction_market/scripts/optimize_position_strategy.py:98, in PositionStrategyOptimizer.step1_load_predictions(self, return_model_dir, risk_model_dir)
#      95 with Timer("Prediction Loading", logger):
#      96     # Load data
#      97     logger.info("\n1.1 Loading training data...")
# ---> 98     train_df, _ = self.data_loader.load_data()
#      99     logger.info(f"✓ Loaded {len(train_df)} samples with {train_df.shape[1]} columns")
#     101     # Preprocess data (same as optimize_return_model.py)
#
# File ~/projects/hull_prediction_market/src/data.py:75, in DataLoader.load_data(self, train_path, test_path)
#      72 test_path = test_path or self.data_dir / 'test.csv'
#      74 logger.info(f"Loading train data from {train_path}")
# ---> 75 self.train_df = pd.read_csv(train_path)
#      77 logger.info(f"Loading test data from {test_path}")
#      78 self.test_df = pd.read_csv(test_path)
#
# File ~/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/projects/hull_prediction_market/venv/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/raw/train.csv'
# ✅ Position strategy optimization complete!
# 📊 Strategy saved to: artifacts/position_strategy.json

# %% [markdown]
# ## 🎉 Training Complete!
#
# ### 생성된 파일들:
#
# ```
# artifacts/
# ├── models_optimized/
# │   ├── return_model.pkl          ← Return prediction model
# │   ├── feature_importance.json   ← Feature importance
# │   └── cv_results.json            ← Cross-validation results
# ├── models_risk_optimized/
# │   ├── risk_model.pkl             ← Risk prediction model
# │   ├── feature_importance.json
# │   └── cv_results.json
# └── position_strategy.json         ← Position mapping strategy
# ```
#
# ---
#
# ## 📦 다음 단계: Kaggle Dataset에 업로드
#
# ### 방법 1: ZIP으로 압축 (추천)
#
# ```bash
# cd ..
# zip -r mydata.zip src/ scripts/ conf/ artifacts/ -x "*.pyc" -x "__pycache__/*"
# ```
#
# 그 다음:
# 1. https://www.kaggle.com/datasets 접속
# 2. "New Dataset" 클릭
# 3. `mydata.zip` 업로드
# 4. Title: `mydata`
# 5. "Create" 클릭
#
# ---
#
# ### 방법 2: 업로드 스크립트 사용
#
# ```bash
# cd submissions
# ./upload_to_kaggle.sh
# ```
#
# ---
#
# ## ✅ 업로드 완료 후:
#
# `kaggle_inference_server.ipynb` (원본)을 Kaggle Notebook으로 제출하세요!
#
# **Good luck! 🚀**
